# %%
import numpy as np
from sympy import Matrix
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Create a 2x3 matrix with float values
matrix = np.array([[3.4, 5.5, 3.3],
                   [4.2, 1.4, 4.4]])

print("Matrix:")
print(matrix)


max_value = np.max(matrix)
min_value = np.min(matrix)

max_index = np.unravel_index(np.argmax(matrix), matrix.shape)
min_index = np.unravel_index(np.argmin(matrix), matrix.shape)

print("\nMaximum Value:", max_value)
print("Maximum Index:", max_index)

print("\nMinimum Value:", min_value)
print("Minimum Index:", min_index)


# Vector Length (Euclidean Norm)

vector_length = np.linalg.norm(matrix)
print("\nVector Length:", vector_length)


# Sorting

# Row-wise descending
row_desc = np.sort(matrix, axis=1)[:, ::-1]
print("\nRow-wise Descending Sort:")
print(row_desc)

# Entire matrix descending
entire_desc = np.sort(matrix.flatten())[::-1]
print("\nEntire Matrix Descending:")
print(entire_desc)


# Sum and Product

print("\nSum:", np.sum(matrix))
print("Product:", np.prod(matrix))


# Median, Mean, Standard Deviation

print("\nMedian:", np.median(matrix))
print("Mean:", np.mean(matrix))
print("Standard Deviation:", np.std(matrix))


# Bonus: Heatmap Visualization

plt.figure(figsize=(5, 2))
sns.heatmap(matrix, annot=True, cmap="YlGnBu", fmt=".1f")
plt.title("2x3 Matrix Heatmap")
plt.show()


# Bonus: Random Matrix Example

random_matrix = np.random.uniform(1, 10, (2, 3))

print("\nRandom 2x3 Matrix:")
print(random_matrix)
# Out:
# Matrix:
# [[3.4 5.5 3.3]
#  [4.2 1.4 4.4]]
#
# Maximum Value: 5.5
# Maximum Index: (np.int64(0), np.int64(1))
#
# Minimum Value: 1.4
# Minimum Index: (np.int64(1), np.int64(1))
#
# Vector Length: 9.573922915921143
#
# Row-wise Descending Sort:
# [[5.5 3.4 3.3]
#  [4.4 4.2 1.4]]
#
# Entire Matrix Descending:
# [5.5 4.4 4.2 3.4 3.3 1.4]
#
# Sum: 22.199999999999996
# Product: 1596.5611199999996
#
# Median: 3.8
# Mean: 3.6999999999999993
# Standard Deviation: 1.2596295751794124
# Random 2x3 Matrix:
# [[6.42738589 7.33756577 9.26260874]
#  [7.7443473  5.37537726 2.38026906]]

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


# Create a 3x2 matrix

matrix = np.array([
    [5.4, -3.4],
    [2.2, 6.6],
    [-4.4, 0.5]
])

print("Original Matrix:")
print(matrix)

# 1. Trigonometric Functions

print("\nSin:")
print(np.sin(matrix))

print("\nCos:")
print(np.cos(matrix))

print("\nTan:")
print(np.tan(matrix))

# Clip values between -1 and 1
clipped_matrix = np.clip(matrix, -1, 1)

print("\nArcsin:")
print(np.arcsin(clipped_matrix))

print("\nArccos:")
print(np.arccos(clipped_matrix))

print("\nArctan:")
print(np.arctan(matrix))


# 2. Exponential and Logarithmic Functions

print("\nExponential:")
print(np.exp(matrix))

# Logarithm requires positive numbers
positive_matrix = np.abs(matrix) + 1

print("\nNatural Log:")
print(np.log(positive_matrix))

print("\nLog base 10:")
print(np.log10(positive_matrix))


# 3. Absolute Value and Square Root

print("\nAbsolute Value:")
print(np.abs(matrix))

# Square root needs non-negative values
sqrt_matrix = np.sqrt(np.abs(matrix))

print("\nSquare Root:")
print(sqrt_matrix)


# 4. Remainder when divided by 2

print("\nRemainder after division by 2:")
print(np.remainder(matrix, 2))


# 5. Rounding Functions

print("\nRound:")
print(np.round(matrix))

print("\nFloor:")
print(np.floor(matrix))

print("\nCeil:")
print(np.ceil(matrix))


# 6. Vector Functions

vector = np.array([3, 4, 5, 6, 7])

print("\nVector:")
print(vector)

print("\nSum:")
print(np.sum(vector))

print("\nMean:")
print(np.mean(vector))

print("\nMaximum:")
print(np.max(vector))

print("\nMinimum:")
print(np.min(vector))

print("\nStandard Deviation:")
print(np.std(vector))


# Bonus: Random Matrix

random_matrix = np.random.uniform(-5, 5, (3, 2))

print("\nRandom Matrix:")
print(random_matrix)


# Bonus: Heatmap Visualization

plt.figure(figsize=(6, 4))
sns.heatmap(
    matrix,
    annot=True,
    cmap="coolwarm",
    linewidths=0.5
)

plt.title("3x2 Matrix Heatmap")
plt.show()
# Out:
# Original Matrix:
# [[ 5.4 -3.4]
#  [ 2.2  6.6]
#  [-4.4  0.5]]
#
# Sin:
# [[-0.77276449  0.2555411 ]
#  [ 0.8084964   0.31154136]
#  [ 0.95160207  0.47942554]]
#
# Cos:
# [[ 0.63469288 -0.96679819]
#  [-0.58850112  0.95023259]
#  [-0.30733287  0.87758256]]
#
# Tan:
# [[-1.21754082 -0.2643169 ]
#  [-1.37382306  0.32785801]
#  [-3.09632378  0.54630249]]
#
# Arcsin:
# [[ 1.57079633 -1.57079633]
#  [ 1.57079633  1.57079633]
#  [-1.57079633  0.52359878]]
#
# Arccos:
# [[0.         3.14159265]
#  [0.         0.        ]
#  [3.14159265 1.04719755]]
#
# Arctan:
# [[ 1.38768551 -1.28474489]
#  [ 1.14416883  1.4204249 ]
#  [-1.34731973  0.46364761]]
#
# Exponential:
# [[2.21406416e+02 3.33732700e-02]
#  [9.02501350e+00 7.35095189e+02]
#  [1.22773399e-02 1.64872127e+00]]
#
# Natural Log:
# [[1.85629799 1.48160454]
#  [1.16315081 2.02814825]
#  [1.68639895 0.40546511]]
#
# Log base 10:
# [[0.80617997 0.64345268]
#  [0.50514998 0.88081359]
#  [0.73239376 0.17609126]]
#
# Absolute Value:
# ...
